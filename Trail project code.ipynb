# %%
#importing libraries
import pandas as pd
import numpy as np

# %%
#reading the data file
test = pd.read_csv("Test.csv")
train = pd.read_csv("Train.csv")

# %%
#to show the first five rows
test.head()
# Out:
#     Applicant_ID  form_field1  form_field2  form_field3  form_field4  \
# 0  Apcnt_1000032       3236.0      0.34875      10.2006       0.0000
# 1  Apcnt_1000048       3284.0      1.27360       2.9606       9.0198
# 2  Apcnt_1000052          NaN      0.27505       0.0600       0.0000
# 3  Apcnt_1000076       3232.0      0.28505       2.8032       0.0000
# 4  Apcnt_1000080       3466.0      2.09545       0.8318       2.5182
#
#    form_field5  form_field6  form_field7  form_field8  form_field9  ...  \
# 0          0.0     418564.0     418564.0     418564.0     540710.0  ...
# 1          0.0          0.0    9858816.0      49014.0    1510098.0  ...
# 2          0.0          NaN          NaN          NaN          NaN  ...
# 3          0.0          0.0     473802.0     473802.0    1724437.0  ...
# 4          0.0      19839.0    1150662.0    1150662.0    7860523.0  ...
#
#    form_field41  form_field42  form_field43  form_field44  form_field45  \
# ...

# %%
#to show the last five rows
test.tail()
# Out:
#        Applicant_ID  form_field1  form_field2  form_field3  form_field4  \
# 23995  Apcnt_999940       3258.0      0.37925       0.5698       5.1282
# 23996  Apcnt_999956       3514.0      0.95260       0.0000       0.0000
# 23997  Apcnt_999976       3302.0      0.05755       4.2394       0.0000
# 23998  Apcnt_999984       3334.0      0.75670       1.4428       0.0000
# 23999  Apcnt_999992       3324.0      0.44840       2.3170       6.7176
#
#        form_field5  form_field6  form_field7  form_field8  form_field9  ...  \
# 23995       0.0000          NaN    2280318.0          NaN          NaN  ...
# 23996       0.0000    1494538.0    4773419.0    4773419.0   89718571.0  ...
# 23997      25.4376          NaN      49403.0          NaN          NaN  ...
# 23998       0.0000          0.0    2513329.0      37733.0     393668.0  ...
# 23999       0.0000          NaN    5305182.0          NaN   18885950.0  ...
#
# ...

# %%
#to show the summary of the data
test.describe()
# Out:
#         form_field1   form_field2   form_field3   form_field4   form_field5  \
# count  22890.000000  22291.000000  23854.000000  23854.000000  23854.000000
# mean    3492.284404      0.557676      1.065443      0.859146      2.183538
# std      190.502764      0.826543      2.198444      3.403115     11.415706
# min     2986.000000      0.000000      0.000000      0.000000      0.000000
# 25%     3356.000000      0.068675      0.000000      0.000000      0.000000
# 50%     3484.000000      0.273250      0.058200      0.000000      0.000000
# 75%     3624.000000      0.728850      1.304250      0.000000      0.000000
# max     3900.000000     22.315050     34.541400    206.452800    297.885600
#
#         form_field6   form_field7   form_field8   form_field9  form_field10  \
# count  1.839600e+04  2.176900e+04  1.839600e+04  2.060000e+04  2.385300e+04
# mean   6.263036e+05  6.797033e+06  2.654142e+06  1.350593e+07  1.187478e+07
# ...

# %%
#to print out the shape(i.e number of rows and columns)
print("Test data shape:", test.shape)
print("Train data shape:", train.shape)
# Out:
# Test data shape: (24000, 51)
# Train data shape: (56000, 52)

# %%
train.head()
# Out:
#     Applicant_ID  form_field1  form_field2  form_field3  form_field4  \
# 0  Apcnt_1000000       3436.0      0.28505       1.6560          0.0
# 1  Apcnt_1000004       3456.0      0.67400       0.2342          0.0
# 2  Apcnt_1000008       3276.0      0.53845       3.1510          0.0
# 3  Apcnt_1000012       3372.0      0.17005       0.5050          0.0
# 4  Apcnt_1000016       3370.0      0.77270       1.1010          0.0
#
#    form_field5  form_field6  form_field7  form_field8  form_field9  ...  \
# 0        0.000          0.0   10689720.0     252072.0    4272776.0  ...
# 1        0.000          0.0     898979.0     497531.0    9073814.0  ...
# 2        6.282          NaN     956940.0          NaN     192944.0  ...
# 3        0.000     192166.0    3044703.0     385499.0    3986472.0  ...
# 4        0.000       1556.0     214728.0     214728.0    1284089.0  ...
#
#    form_field42  form_field43  form_field44  form_field45  form_field46  \
# ...

# %%
train.tail()
# Out:
#        Applicant_ID  form_field1  form_field2  form_field3  form_field4  \
# 55995  Apcnt_999968       3740.0      0.01730       0.0000       0.0000
# 55996  Apcnt_999972       3360.0      2.01145       0.6252       0.0000
# 55997  Apcnt_999980       3500.0      0.76640       0.0000       0.0000
# 55998  Apcnt_999988       3280.0      0.05235       2.0916       2.2212
# 55999  Apcnt_999996       3522.0      0.46930       0.0000       0.0000
#
#        form_field5  form_field6  form_field7  form_field8  form_field9  ...  \
# 55995          0.0     770998.0    9637475.0    4047934.0   11641992.0  ...
# 55996          0.0          NaN     927765.0          NaN          NaN  ...
# 55997          0.0     118645.0    3662435.0    3662435.0    3585024.0  ...
# 55998          0.0          NaN    3458599.0          NaN     115533.0  ...
# 55999          0.0      98806.0    2053920.0     523983.0   14903368.0  ...
#
# ...

# %%
train.describe()
# Out:
#         form_field1   form_field2   form_field3   form_field4   form_field5  \
# count  53471.000000  52156.000000  55645.000000  55645.000000  55645.000000
# mean    3491.795665      0.550737      1.052225      0.851979      1.956317
# std      188.462426      0.820979      2.147768      3.157692     10.512396
# min     2990.000000      0.000000      0.000000      0.000000      0.000000
# 25%     3358.000000      0.070788      0.000000      0.000000      0.000000
# 50%     3484.000000      0.267575      0.062000      0.000000      0.000000
# 75%     3620.000000      0.719512      1.282000      0.000000      0.000000
# max     3900.000000     18.015050     57.371600     91.672200    407.748600
#
#         form_field6   form_field7   form_field8   form_field9  form_field10  \
# count  4.264000e+04  5.083700e+04  4.264000e+04  4.799200e+04  5.564500e+04
# mean   6.244479e+05  6.865210e+06  2.626690e+06  1.316002e+07  1.185585e+07
# ...

# %%
#to show the columns in the data file
test.isnull().sum()
# Out:
# Applicant_ID        0
# form_field1      1110
# form_field2      1709
# form_field3       146
# form_field4       146
# form_field5       146
# form_field6      5604
# form_field7      2231
# form_field8      5604
# form_field9      3400
# form_field10      147
# form_field11    13398
# form_field12     4183
# form_field13     2463
# form_field14        0
# form_field15     9592
# form_field16     5474
# form_field17     4695
# form_field18     4369
# form_field19        0
# form_field20      147
# form_field21     6707
# form_field22     8724
# form_field23    12125
# form_field24     5605
# form_field25     2256
# form_field26     3172
# form_field27     3910
# form_field28      147
# form_field29      147
# form_field30    10908
# form_field31    16810
# form_field32     2256
# form_field33      495
# form_field34      147
# form_field35     9866
# form_field36      903
# form_field37     2256
# form_field38      147
# form_field39     1829
# form_field40    18828
# ...

# %%
train.isnull().sum()
# Out:
# Applicant_ID          0
# form_field1        2529
# form_field2        3844
# form_field3         355
# form_field4         355
# form_field5         355
# form_field6       13360
# form_field7        5163
# form_field8       13360
# form_field9        8008
# form_field10        355
# form_field11      31421
# form_field12       9895
# form_field13       5889
# form_field14          0
# form_field15      22475
# form_field16      13036
# form_field17      11151
# form_field18      10402
# form_field19          4
# form_field20        355
# form_field21      15854
# form_field22      20400
# form_field23      28123
# form_field24      13297
# form_field25       5450
# form_field26       7438
# form_field27       9299
# form_field28        355
# form_field29        355
# form_field30      25509
# form_field31      39408
# form_field32       5450
# form_field33       1256
# form_field34        355
# form_field35      23148
# form_field36       1995
# form_field37       5450
# ...

# %%
#test['default_status'] = 1

# %%
#to extract the features and target
X_train = train.drop('default_status', axis=1)
y_train = train['default_status']

# %%
#X_test = test.drop('default_status', axis=1)
#y_test = test['default_status']

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
#I replaced the strings with an integer
X_train['form_field47'] = train['form_field47'].replace({'charge': 1, 'lending': 0})
test['form_field47'] = test['form_field47'].replace({'charge': 1, 'lending': 0})
#['default_status'] = train['default_status'].replace({'yes': 1, 'no': 0})

# %%
test.fillna(0, inplace = True)
X_train.fillna(0, inplace = True)

# %%
#train.drop(columns = ['Applicant_ID', ], axis=1)
#test.drop(columns = ['Applicant_ID'], axis=1)

# %%
X_train.head()
# Out:
#     Applicant_ID  form_field1  form_field2  form_field3  form_field4  \
# 0  Apcnt_1000000       3436.0      0.28505       1.6560          0.0
# 1  Apcnt_1000004       3456.0      0.67400       0.2342          0.0
# 2  Apcnt_1000008       3276.0      0.53845       3.1510          0.0
# 3  Apcnt_1000012       3372.0      0.17005       0.5050          0.0
# 4  Apcnt_1000016       3370.0      0.77270       1.1010          0.0
#
#    form_field5  form_field6  form_field7  form_field8  form_field9  ...  \
# 0        0.000          0.0   10689720.0     252072.0    4272776.0  ...
# 1        0.000          0.0     898979.0     497531.0    9073814.0  ...
# 2        6.282          0.0     956940.0          0.0     192944.0  ...
# 3        0.000     192166.0    3044703.0     385499.0    3986472.0  ...
# 4        0.000       1556.0     214728.0     214728.0    1284089.0  ...
#
#    form_field41  form_field42  form_field43  form_field44  form_field45  \
# ...

# %%
numerical_columns = X_train.select_dtypes(include=[np.number]).columns
numerical_columns2 = test.select_dtypes(include=[np.number]).columns

# %%
scaler = StandardScaler()
#scaler.fit(train)
train_data_scaled = scaler.fit_transform(X_train[numerical_columns])
test_data_scaled = scaler.transform(test[numerical_columns2])

# %%
col = X_train.columns
col2 = test.columns

# %%
#Creating a dataframe
train = pd.DataFrame(columns = col)
test = pd.DataFrame(columns = col2)

# %% [markdown]
# # Using regression to predict

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
y_train = y_train.replace({'yes': 1, 'no': 0})

# %%
model = LogisticRegression()
model.fit(train_data_scaled, y_train)
# Out:
# LogisticRegression()

# %%
rfc = RandomForestClassifier(n_estimators=100, random_state=42)
rfc.fit(train_data_scaled, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rfc.predict(test_data_scaled)

# %%
y_pred = model.predict(test_data_scaled)

# %%
applicant = X_test["Applicant_ID"]

# %%
result = pd.DataFrame({'Applicant_IDs':applicant, 'defaults':y_pred})
# Show first 20 rows
result.head(20).round(2)
# Out:
#     Applicant_IDs  defaults
# 0   Apcnt_1000032         0
# 1   Apcnt_1000048         0
# 2   Apcnt_1000052         0
# 3   Apcnt_1000076         1
# 4   Apcnt_1000080         0
# 5   Apcnt_1000084         0
# 6   Apcnt_1000104         0
# 7   Apcnt_1000116         1
# 8   Apcnt_1000128         0
# 9   Apcnt_1000156         0
# 10  Apcnt_1000192         0
# 11  Apcnt_1000208         0
# 12  Apcnt_1000264         1
# 13  Apcnt_1000288         0
# 14  Apcnt_1000292         0
# 15  Apcnt_1000328         1
# 16  Apcnt_1000336         0
# 17  Apcnt_1000356         0
# 18  Apcnt_1000368         0
# 19  Apcnt_1000372         1

# %%
result.to_csv("TrailProject.csv", index=False)

# %% [markdown]
# # Evaluating model performance on test data

# %%
#predict probabilities of default
y_pred_probability = model.predict_proba(test_data_scaled)[:,1]
#identify likely defaulters
likely_defaulters = test_data_scaled[y_pred_probability > 0.5]

# %%
#Analyzing the results
print("Likely Defaulters:\n", likely_defaulters)

print("Defaulters' average credit score:\n", likely_defaulters.mean())
# Out:
# Likely Defaulters:
#  [[-1.36481406e-01 -2.83281971e-01  8.20348863e-01 ... -1.45687467e-01
#   -1.40706976e-01 -9.19978567e-02]
#  [-5.09329704e-02 -1.18694957e-01 -3.07831455e-02 ... -1.45756135e-01
#   -5.78366821e-01 -9.19978765e-02]
#  [-3.48926386e-02  2.06811915e-01 -3.76631368e-01 ... -1.45550524e-01
#    1.21344966e+00 -9.19978646e-02]
#  ...
#  [-1.63215293e-01  1.13696474e+00  1.45193026e+00 ... -1.45756135e-01
#    1.46711470e+00 -9.19978765e-02]
#  [-1.01727354e-01 -1.66181542e-01 -2.22049814e-01 ... -1.45756135e-01
#   -5.78366821e-01 -9.19978765e-02]
#  [-1.38586557e-04  3.03028191e-01  1.85406998e-01 ... -1.45735325e-01
#   -1.24104520e-01 -9.19978720e-02]]
# Defaulters' average credit score:
#  0.07835265238166188

# %%
#Validating the model
actual_defaulters = test_data_scaled[test_data_scaled == 1]
print("Actual Defaulters:\n", actual_defaulters)
# Out:
# Actual Defaulters:
#  []
